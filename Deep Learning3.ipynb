# %%
import pandas as pd
import numpy as np
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import StratifiedKFold
df=pd.read_csv("pima-indians-diabetes.csv",header=None)
df
# Out:
#       0    1   2   3    4     5      6   7  8
# 0     6  148  72  35    0  33.6  0.627  50  1
# 1     1   85  66  29    0  26.6  0.351  31  0
# 2     8  183  64   0    0  23.3  0.672  32  1
# 3     1   89  66  23   94  28.1  0.167  21  0
# 4     0  137  40  35  168  43.1  2.288  33  1
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 763  10  101  76  48  180  32.9  0.171  63  0
# 764   2  122  70  27    0  36.8  0.340  27  0
# 765   5  121  72  23  112  26.2  0.245  30  0
# 766   1  126  60   0    0  30.1  0.349  47  1
# 767   1   93  70  31    0  30.4  0.315  23  0
#
# [768 rows x 9 columns]

# %%
x=df.iloc[:,0:8].values
y=df.iloc[:,8].values

# %%
KFold=StratifiedKFold(n_splits=10,shuffle=True,random_state=0)

# %%
cvscore=[]
for train,test in KFold.split(x,y):
   model=Sequential()
   layers12=Dense(10,input_shape=(8,),activation="relu")
   layers3=Dense(20,activation="relu")
   layers4=Dense(1,activation="sigmoid")
   model.add(layers12)
   model.add(layers3)
   model.add(layers4)
   model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
   model.fit(x[train],y[train],epochs=100,batch_size=10,verbose=0)
   scores=model.evaluate(x[test],y[test])
# Out:
# C:\Users\rajes\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6788 - loss: 0.6147
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7191 - loss: 0.6339
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7438 - loss: 0.5575
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6814 - loss: 0.6391
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7243 - loss: 0.5192
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7243 - loss: 0.8389
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7880 - loss: 0.5486
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7204 - loss: 0.5758
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7985 - loss: 0.4887
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7473 - loss: 0.7120

# %%
scores[0]
# Out:
# 0.7441347241401672

# %%
scores[1]
# Out:
# 0.7368420958518982

# %%
np.average(scores)
# Out:
# np.float64(0.7404884099960327)

# %%
cvscore.append(scores[1]*100)

# %%
np.mean(cvscore)
# Out:
# np.float64(73.68420958518982)

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import StratifiedKFold
df=pd.read_csv("pima-indians-diabetes.csv")
df
# Out:
#       6  148  72  35    0  33.6  0.627  50  1
# 0     1   85  66  29    0  26.6  0.351  31  0
# 1     8  183  64   0    0  23.3  0.672  32  1
# 2     1   89  66  23   94  28.1  0.167  21  0
# 3     0  137  40  35  168  43.1  2.288  33  1
# 4     5  116  74   0    0  25.6  0.201  30  0
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 762  10  101  76  48  180  32.9  0.171  63  0
# 763   2  122  70  27    0  36.8  0.340  27  0
# 764   5  121  72  23  112  26.2  0.245  30  0
# 765   1  126  60   0    0  30.1  0.349  47  1
# 766   1   93  70  31    0  30.4  0.315  23  0
#
# [767 rows x 9 columns]

# %%
x=df.iloc[:,0:8].values
y=df.iloc[:,8].values

# %%
kfold=StratifiedKFold(n_splits=5,shuffle=True,random_state=0)
cvscore=[]
for train,test in KFold.split(x,y):
    model=Sequential()
    layers12=Dense(10,input_shape=(8,),activation="relu")
    layers3=Dense(20,activation="relu")
    layers4=Dense(1,activation="sigmoid")
    model.add(layers12)
    model.add(layers3)
    model.add(layers4)
    model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
    model.fit(x[train],y[train],epochs=50,batch_size=10,verbose=0)
    values=model.evaluate(x[test],y[test])
# Out:
# C:\Users\rajes\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6905 - loss: 0.5981
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6514 - loss: 0.6564
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6619 - loss: 0.6329
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7100 - loss: 0.5522
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7321 - loss: 0.5629
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7035 - loss: 0.6163
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7022 - loss: 0.5310
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7173 - loss: 0.5275
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6429 - loss: 0.6487
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7264 - loss: 0.5543

# %%
values[0]
# Out:
# 0.5898000001907349

# %%
values[1]
# Out:
# 0.7105262875556946

# %%
np.average(values)
# Out:
# np.float64(0.6501631438732147)

# %%
cvscore.append(values[1])
np.average(cvscore)
# Out:
# np.float64(0.7105262875556946)

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
df=pd.read_csv("pima-indians-diabetes.csv",header=None)
df
# Out:
#       0    1   2   3    4     5      6   7  8
# 0     6  148  72  35    0  33.6  0.627  50  1
# 1     1   85  66  29    0  26.6  0.351  31  0
# 2     8  183  64   0    0  23.3  0.672  32  1
# 3     1   89  66  23   94  28.1  0.167  21  0
# 4     0  137  40  35  168  43.1  2.288  33  1
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 763  10  101  76  48  180  32.9  0.171  63  0
# 764   2  122  70  27    0  36.8  0.340  27  0
# 765   5  121  72  23  112  26.2  0.245  30  0
# 766   1  126  60   0    0  30.1  0.349  47  1
# 767   1   93  70  31    0  30.4  0.315  23  0
#
# [768 rows x 9 columns]

# %%
x=df.iloc[:,0:8].values
y=df.iloc[:,8].values

# %%
model=Sequential()
layers12=Dense(10,input_shape=(8,),activation="relu")
layers3=Dense(20,activation="relu")
layers4=Dense(1,activation="sigmoid")
model.add(layers12)
model.add(layers3)
model.add(layers4)
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
model.fit(x,y,epochs=90,batch_size=10,verbose=0)
# Out:
# C:\Users\rajes\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
l,acc=model.evaluate(x,y)
l,acc
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7010 - loss: 0.5745
# (0.5345599055290222, 0.72265625)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 10)                  │              90 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 20)                  │             220 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              21 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 995 (3.89 KB)
#  Trainable params: 331 (1.29 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 664 (2.60 KB)

# %%
x=[[5,121,72,23,112,26.2,0.245,30]]
out=np.array(x)
model.predict(out)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# array([[0.21663643]], dtype=float32)

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
df=pd.read_csv("pima-indians-diabetes.csv",header=None)
df
# Out:
#       0    1   2   3    4     5      6   7  8
# 0     6  148  72  35    0  33.6  0.627  50  1
# 1     1   85  66  29    0  26.6  0.351  31  0
# 2     8  183  64   0    0  23.3  0.672  32  1
# 3     1   89  66  23   94  28.1  0.167  21  0
# 4     0  137  40  35  168  43.1  2.288  33  1
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 763  10  101  76  48  180  32.9  0.171  63  0
# 764   2  122  70  27    0  36.8  0.340  27  0
# 765   5  121  72  23  112  26.2  0.245  30  0
# 766   1  126  60   0    0  30.1  0.349  47  1
# 767   1   93  70  31    0  30.4  0.315  23  0
#
# [768 rows x 9 columns]

# %%
x=df.iloc[:,0:8].values
y=df.iloc[:,8].values

# %%
model=Sequential()
layers12=Dense(10,input_shape=(8,),activation="relu")
layers3=Dense(20,activation="relu")
layers4=Dense(1,activation="sigmoid")
model.add(layers12)
model.add(layers3)
model.add(layers4)
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
model.fit(x,y,epochs=50,batch_size=10,validation_split=0.2)
# Out:
# Epoch 1/50
# C:\Users\rajes\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6401 - loss: 11.8985 - val_accuracy: 0.4805 - val_loss: 3.1556
# Epoch 2/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5630 - loss: 2.1997 - val_accuracy: 0.6169 - val_loss: 1.0653
# Epoch 3/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6572 - loss: 0.9453 - val_accuracy: 0.5844 - val_loss: 0.8267
# Epoch 4/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6339 - loss: 0.7911 - val_accuracy: 0.5779 - val_loss: 0.7812
# Epoch 5/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6278 - loss: 0.8105 - val_accuracy: 0.5779 - val_loss: 0.8008
# Epoch 6/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6601 - loss: 0.7160 - val_accuracy: 0.5974 - val_loss: 0.7522
# Epoch 7/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6971 - loss: 0.6656 - val_accuracy: 0.6558 - val_loss: 0.7078
# Epoch 8/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6780 - loss: 0.6891 - val_accuracy: 0.6299 - val_loss: 0.7081
# Epoch 9/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6647 - loss: 0.6735 - val_accuracy: 0.5974 - val_loss: 0.7348
# Epoch 10/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6926 - loss: 0.6724 - val_accuracy: 0.6234 - val_loss: 0.6929
# Epoch 11/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6981 - loss: 0.6512 - val_accuracy: 0.6234 - val_loss: 0.7478
# Epoch 12/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6882 - loss: 0.6387 - val_accuracy: 0.6169 - val_loss: 0.6883
# Epoch 13/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6565 - loss: 0.6731 - val_accuracy: 0.6429 - val_loss: 0.6855
# Epoch 14/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7156 - loss: 0.5975 - val_accuracy: 0.6364 - val_loss: 0.6819
# Epoch 15/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7394 - loss: 0.5960 - val_accuracy: 0.6234 - val_loss: 0.6753
# Epoch 16/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7183 - loss: 0.5740 - val_accuracy: 0.6429 - val_loss: 0.6715
# Epoch 17/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7477 - loss: 0.5333 - val_accuracy: 0.6364 - val_loss: 0.6573
# Epoch 18/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7168 - loss: 0.6096 - val_accuracy: 0.6234 - val_loss: 0.6811
# Epoch 19/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6786 - loss: 0.6288 - val_accuracy: 0.6429 - val_loss: 0.6603
# Epoch 20/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7154 - loss: 0.5676 - val_accuracy: 0.6429 - val_loss: 0.6742
# Epoch 21/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7498 - loss: 0.5670 - val_accuracy: 0.5844 - val_loss: 0.6842
# Epoch 22/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7110 - loss: 0.5659 - val_accuracy: 0.5519 - val_loss: 0.7720
# Epoch 23/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6765 - loss: 0.6838 - val_accuracy: 0.6364 - val_loss: 0.6968
# Epoch 24/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7249 - loss: 0.6243 - val_accuracy: 0.5779 - val_loss: 0.6685
# Epoch 25/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7137 - loss: 0.5431 - val_accuracy: 0.6039 - val_loss: 0.6702
# Epoch 26/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7134 - loss: 0.5911 - val_accuracy: 0.6299 - val_loss: 0.6510
# Epoch 27/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7137 - loss: 0.5682 - val_accuracy: 0.6299 - val_loss: 0.6392
# Epoch 28/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6758 - loss: 0.6144 - val_accuracy: 0.6753 - val_loss: 0.6707
# Epoch 29/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7555 - loss: 0.5435 - val_accuracy: 0.6558 - val_loss: 0.6346
# Epoch 30/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7279 - loss: 0.5617 - val_accuracy: 0.6753 - val_loss: 0.6614
# Epoch 31/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7142 - loss: 0.5840 - val_accuracy: 0.5779 - val_loss: 0.7066
# Epoch 32/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7372 - loss: 0.5497 - val_accuracy: 0.5584 - val_loss: 0.7272
# Epoch 33/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6950 - loss: 0.6254 - val_accuracy: 0.6364 - val_loss: 0.6505
# Epoch 34/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7152 - loss: 0.5522 - val_accuracy: 0.6169 - val_loss: 0.6469
# Epoch 35/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7559 - loss: 0.5216 - val_accuracy: 0.6169 - val_loss: 0.7610
# Epoch 36/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7078 - loss: 0.5856 - val_accuracy: 0.6364 - val_loss: 0.6257
# Epoch 37/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6922 - loss: 0.5511 - val_accuracy: 0.5649 - val_loss: 0.6815
# Epoch 38/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7548 - loss: 0.5281 - val_accuracy: 0.6494 - val_loss: 0.6148
# Epoch 39/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7245 - loss: 0.5378 - val_accuracy: 0.6623 - val_loss: 0.6131
# Epoch 40/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7166 - loss: 0.5592 - val_accuracy: 0.5974 - val_loss: 0.6514
# Epoch 41/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7367 - loss: 0.5390 - val_accuracy: 0.6234 - val_loss: 0.6363
# Epoch 42/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7263 - loss: 0.5370 - val_accuracy: 0.6688 - val_loss: 0.6113
# Epoch 43/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7134 - loss: 0.5625 - val_accuracy: 0.6558 - val_loss: 0.6186
# Epoch 44/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7274 - loss: 0.5383 - val_accuracy: 0.6818 - val_loss: 0.6377
# Epoch 45/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7105 - loss: 0.5649 - val_accuracy: 0.6623 - val_loss: 0.6142
# Epoch 46/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7507 - loss: 0.5290 - val_accuracy: 0.6558 - val_loss: 0.6177
# Epoch 47/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7494 - loss: 0.5423 - val_accuracy: 0.6429 - val_loss: 0.6199
# Epoch 48/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7272 - loss: 0.5531 - val_accuracy: 0.6234 - val_loss: 0.6260
# Epoch 49/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7327 - loss: 0.5226 - val_accuracy: 0.5974 - val_loss: 0.6535
# Epoch 50/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7279 - loss: 0.5585 - val_accuracy: 0.7013 - val_loss: 0.6348

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
df=pd.read_csv("pima-indians-diabetes.csv",header=None)
df
# Out:
#       0    1   2   3    4     5      6   7  8
# 0     6  148  72  35    0  33.6  0.627  50  1
# 1     1   85  66  29    0  26.6  0.351  31  0
# 2     8  183  64   0    0  23.3  0.672  32  1
# 3     1   89  66  23   94  28.1  0.167  21  0
# 4     0  137  40  35  168  43.1  2.288  33  1
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 763  10  101  76  48  180  32.9  0.171  63  0
# 764   2  122  70  27    0  36.8  0.340  27  0
# 765   5  121  72  23  112  26.2  0.245  30  0
# 766   1  126  60   0    0  30.1  0.349  47  1
# 767   1   93  70  31    0  30.4  0.315  23  0
#
# [768 rows x 9 columns]

# %%
x=df.iloc[:,0:8].values
y=df.iloc[:,8].values

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
model=Sequential()
layers12=Dense(10,input_shape=(8,),activation="relu")
layers3=Dense(20,activation="relu")
layers4=Dense(1,activation="sigmoid")
model.add(layers12)
model.add(layers3)
model.add(layers4)
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
model.fit(X_train,Y_train,epochs=40,batch_size=10,validation_data=[X_test,Y_test])
# Out:
# Epoch 1/40
# C:\Users\rajes\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5508 - loss: 4.3821 - val_accuracy: 0.5779 - val_loss: 1.9884
# Epoch 2/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5279 - loss: 1.9900 - val_accuracy: 0.5455 - val_loss: 1.6510
# Epoch 3/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5089 - loss: 1.6368 - val_accuracy: 0.5584 - val_loss: 1.2905
# Epoch 4/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5207 - loss: 1.4441 - val_accuracy: 0.5779 - val_loss: 1.1001
# Epoch 5/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5322 - loss: 1.2234 - val_accuracy: 0.6169 - val_loss: 0.9618
# Epoch 6/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5213 - loss: 1.0854 - val_accuracy: 0.5260 - val_loss: 0.8968
# Epoch 7/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5367 - loss: 0.9282 - val_accuracy: 0.5909 - val_loss: 0.8144
# Epoch 8/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5637 - loss: 0.9027 - val_accuracy: 0.5584 - val_loss: 0.7860
# Epoch 9/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5998 - loss: 0.8051 - val_accuracy: 0.6494 - val_loss: 0.6992
# Epoch 10/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6271 - loss: 0.7364 - val_accuracy: 0.6948 - val_loss: 0.6946
# Epoch 11/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6245 - loss: 0.7162 - val_accuracy: 0.6948 - val_loss: 0.6682
# Epoch 12/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5719 - loss: 0.8743 - val_accuracy: 0.7078 - val_loss: 0.6255
# Epoch 13/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5888 - loss: 0.7565 - val_accuracy: 0.6883 - val_loss: 0.6502
# Epoch 14/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6340 - loss: 0.6936 - val_accuracy: 0.6688 - val_loss: 0.6036
# Epoch 15/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6461 - loss: 0.6514 - val_accuracy: 0.6169 - val_loss: 0.6582
# Epoch 16/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6294 - loss: 0.8050 - val_accuracy: 0.7208 - val_loss: 0.5993
# Epoch 17/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6176 - loss: 0.7469 - val_accuracy: 0.6818 - val_loss: 0.6686
# Epoch 18/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6346 - loss: 0.7206 - val_accuracy: 0.7078 - val_loss: 0.5795
# Epoch 19/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6710 - loss: 0.6195 - val_accuracy: 0.7143 - val_loss: 0.5816
# Epoch 20/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6610 - loss: 0.7309 - val_accuracy: 0.6948 - val_loss: 0.6001
# Epoch 21/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6691 - loss: 0.6119 - val_accuracy: 0.7013 - val_loss: 0.5980
# Epoch 22/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6746 - loss: 0.6395 - val_accuracy: 0.7078 - val_loss: 0.6080
# Epoch 23/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7003 - loss: 0.6389 - val_accuracy: 0.7078 - val_loss: 0.5841
# Epoch 24/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6396 - loss: 0.6670 - val_accuracy: 0.6429 - val_loss: 0.6475
# Epoch 25/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6777 - loss: 0.6198 - val_accuracy: 0.6039 - val_loss: 0.6956
# Epoch 26/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6690 - loss: 0.6252 - val_accuracy: 0.7273 - val_loss: 0.5609
# Epoch 27/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7099 - loss: 0.6009 - val_accuracy: 0.6753 - val_loss: 0.6032
# Epoch 28/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6972 - loss: 0.6082 - val_accuracy: 0.6883 - val_loss: 0.5947
# Epoch 29/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7146 - loss: 0.6160 - val_accuracy: 0.4545 - val_loss: 1.0252
# Epoch 30/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6629 - loss: 0.6549 - val_accuracy: 0.6883 - val_loss: 0.7021
# Epoch 31/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6547 - loss: 0.6758 - val_accuracy: 0.6364 - val_loss: 0.6884
# Epoch 32/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6816 - loss: 0.6348 - val_accuracy: 0.6883 - val_loss: 0.7470
# Epoch 33/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6729 - loss: 0.7098 - val_accuracy: 0.7078 - val_loss: 0.6825
# Epoch 34/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7285 - loss: 0.6233 - val_accuracy: 0.7403 - val_loss: 0.5487
# Epoch 35/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7143 - loss: 0.5668 - val_accuracy: 0.6429 - val_loss: 0.6674
# Epoch 36/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7141 - loss: 0.6341 - val_accuracy: 0.7338 - val_loss: 0.5490
# Epoch 37/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7563 - loss: 0.5591 - val_accuracy: 0.7208 - val_loss: 0.5531
# Epoch 38/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7152 - loss: 0.5526 - val_accuracy: 0.7208 - val_loss: 0.5663
# Epoch 39/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6712 - loss: 0.6046 - val_accuracy: 0.7013 - val_loss: 0.5679
# Epoch 40/40
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7216 - loss: 0.5542 - val_accuracy: 0.7143 - val_loss: 0.5538

# %%
model.predict(X_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# array([[0.757541  ],
#        [0.15585619],
#        [0.24672358],
#        [0.20113492],
#        [0.33071935],
#        [0.10445033],
#        [0.4864771 ],
#        [0.41069812],
#        [0.4103799 ],
#        [0.41622117],
#        [0.5117326 ],
#        [0.48248222],
#        [0.2709639 ],
#        [0.30186203],
#        [0.25918737],
#        [0.26214406],
#        [0.6464755 ],
#        [0.2245231 ],
#        [0.41231146],
#        [0.33915612],
#        [0.363907  ],
#        [0.23826525],
#        [0.6423154 ],
#        [0.1592314 ],
#        [0.12895128],
#        [0.42625657],
#        [0.18199061],
#        [0.4032754 ],
#        [0.26665053],
#        [0.3679971 ],
#        [0.42710668],
#        [0.272191  ],
#        [0.09430813],
#        [0.6433232 ],
#        [0.40934142],
#        [0.68604636],
#        [0.29620653],
#        [0.10564689],
#        [0.6075336 ],
#        [0.58144075],
#        [0.30451873],
#        [0.17287008],
#        [0.31144497],
#        [0.7166995 ],
#        [0.8389424 ],
#        [0.12388297],
#        [0.2324556 ],
#        [0.34586242],
#        [0.26390478],
#        [0.3098865 ],
#        [0.55149686],
#        [0.35593295],
#        [0.79396486],
#        [0.29764086],
#        [0.1189839 ],
#        [0.6048574 ],
#        [0.18005891],
#        [0.17587516],
#        [0.40278918],
#        [0.1468683 ],
#        [0.34653673],
#        [0.33348733],
#        [0.32511708],
#        [0.39965516],
#        [0.6813358 ],
#        [0.7515861 ],
#        [0.5586365 ],
#        [0.28894058],
#        [0.57170165],
#        [0.25550032],
#        [0.2965942 ],
#        [0.52133256],
#        [0.1648333 ],
#        [0.6432297 ],
#        [0.66825074],
#        [0.32949993],
#        [0.03839102],
#        [0.6173507 ],
#        [0.15008578],
#        [0.22430015],
#        [0.25291836],
#        [0.4341703 ],
#        [0.17634983],
#        [0.17224008],
#        [0.28276262],
#        [0.19548318],
#        [0.58416533],
#        [0.6207281 ],
#        [0.33443722],
#        [0.13162199],
#        [0.25005475],
#        [0.24626976],
#        [0.39475295],
#        [0.11652473],
#        [0.4454664 ],
#        [0.3168194 ],
#        [0.17456563],
#        [0.27848765],
#        [0.5732597 ],
#        [0.34969988],
#        [0.08885557],
#        [0.30689955],
#        [0.16890493],
#        [0.1830487 ],
#        [0.5026984 ],
#        [0.38196236],
#        [0.1291099 ],
#        [0.3949251 ],
#        [0.12950951],
#        [0.68697774],
#        [0.22031261],
#        [0.26205084],
#        [0.67046654],
#        [0.11816942],
#        [0.26926914],
#        [0.5572254 ],
#        [0.12244008],
#        [0.7943399 ],
#        [0.12674077],
#        [0.29935294],
#        [0.24648215],
#        [0.21031637],
#        [0.3016639 ],
#        [0.38941956],
#        [0.31364566],
#        [0.26477095],
#        [0.15578556],
#        [0.32463872],
#        [0.47240275],
#        [0.43400934],
#        [0.45564184],
#        [0.1437402 ],
#        [0.20138092],
#        [0.54470897],
#        [0.28609666],
#        [0.3998318 ],
#        [0.42016155],
#        [0.3431989 ],
#        [0.41221866],
#        [0.5061731 ],
#        [0.21951424],
#        [0.46855906],
#        [0.32074478],
#        [0.05542167],
#        [0.46010295],
#        [0.28333116],
#        [0.1928269 ],
#        [0.3105442 ],
#        [0.19855614],
#        [0.17699601],
#        [0.22265276],
#        [0.32508415],
#        [0.2009015 ],
#        [0.17552039]], dtype=float32)

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import StratifiedKFold
df=pd.read_csv("pima-indians-diabetes.csv")
df
# Out:
#       6  148  72  35    0  33.6  0.627  50  1
# 0     1   85  66  29    0  26.6  0.351  31  0
# 1     8  183  64   0    0  23.3  0.672  32  1
# 2     1   89  66  23   94  28.1  0.167  21  0
# 3     0  137  40  35  168  43.1  2.288  33  1
# 4     5  116  74   0    0  25.6  0.201  30  0
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 762  10  101  76  48  180  32.9  0.171  63  0
# 763   2  122  70  27    0  36.8  0.340  27  0
# 764   5  121  72  23  112  26.2  0.245  30  0
# 765   1  126  60   0    0  30.1  0.349  47  1
# 766   1   93  70  31    0  30.4  0.315  23  0
#
# [767 rows x 9 columns]

# %%
x=df.iloc[:,0:8].values
y=df.iloc[:,8].values

# %%
score=StratifiedKFold(n_splits=5,shuffle=True,random_state=0)

# %%
values=[]
for train,test in score.split(x,y):
    model=Sequential()
    layers12=Dense(10,input_shape=(8,),activation="relu")
    layers3=Dense(20,activation="relu")
    layers4=Dense(1,activation="sigmoid")
    model.add(layers12)
    model.add(layers3)
    model.add(layers4)
    model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
    model.fit(x[train],y[train],epochs=150,batch_size=10,verbose=0)
    final=model.evaluate(x[test],y[test])
# Out:
# C:\Users\rajes\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7003 - loss: 0.5613
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7442 - loss: 0.5440
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6975 - loss: 0.6239
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7236 - loss: 0.6577
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7054 - loss: 0.6080

# %%
final[0]
# Out:
# 0.5625483393669128

# %%
final[1]
# Out:
# 0.7385621070861816

# %%
np.mean(final*100)
# Out:
# np.float64(0.6505552232265472)
